# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Diool/Amer_Op_Neural_Net/amer_op_neural_net')
#pwd

# %%
ls
# Out:
# American_option.ipynb  config.py    myplot.py      __pycache__/
# amer_op_neural_net/    __init__.py  neural_net.py  README.md
# amer_op.py             main.py      options.py     Results/

# %%
from google.colab import files
#src = list(files.upload().values())[0]
#open('operation.py','wb').write(src)
#import operation

# %%
#import __init__
#import config
#import amer_op
#import options
#import neural_net
#import myplot

# %%
import main
# Out:
#  Number of CPUs:  2
#
#  directory:  Results/option=call&geometric&vanilla_d=7_X0=1p0_N=10_seed=347161/
#
#  Simulation size:  720000
#
#  AmericanOption, initialization, phase 1 :
#    0 (0.09, 0.74), 1 (0.53, 1.19), 2 (0.46, 1.13), 3 (0.43, 1.11), 4 (0.45, 1.12), 5 (0.46, 1.14), 6 (0.44, 1.11), 7 (0.45, 1.12), 8 (0.47, 1.16), 9 (0.46, 1.12), 10 (0.54, 1.30),
#  evolution_state, time:  12.28
#
#  AmericanOption, initialization, phase 2 :
#    0 (0.60), 1 (0.58), 2 (0.58), 3 (0.58), 4 (0.60), 5 (0.60), 6 (0.59), 7 (0.58), 8 (0.58), 9 (0.59), 10 (0.58),
#  initialize_results, time:  6.70
#
#
# ************** Main Script: Neural Network **************
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-63b75181c34a> in <module>
# ----> 1 import main
#
# /content/drive/MyDrive/Diool/Amer_Op_Neural_Net/amer_op_neural_net/main.py in <module>
#      16 print("\n\n************** Main Script: Neural Network **************\n")
#      17 dim_layers = [None, d + 5, d + 5, d + 5, d + 5, d + 5, d + 5, d + 5, 1]
# ---> 18 NN = NeuralNet(NN_name="AmerOp", dim_layers=dim_layers)
#      19
#      20 ## Main Script: Neural Network
#
# /content/drive/MyDrive/Diool/Amer_Op_Neural_Net/amer_op_neural_net/amer_op_neural_net/neural_net.py in __init__(self, NN_name, dim_layers)
#      24
#      25         with tf.compat.v1.variable_scope(self.NN_name, reuse=tf.compat.v1.AUTO_REUSE):
# ---> 26             self.build_hyperparams()
#      27             self.build_dataset()
#      28
#
# /content/drive/MyDrive/Diool/Amer_Op_Neural_Net/amer_op_neural_net/amer_op_neural_net/neural_net.py in build_hyperparams(self)
#      59                                            initializer=tf.constant_initializer(0), trainable=False)
#      60         ## self.rate: Global learning rate of the Adam optimizer
# ---> 61         self.rate = tf.compat.v1.cast(tf.compat.v1.train.exponential_decay(
#      62             self.init_rate, global_step=tf.clip_by_value(self.step - self.n_relaxstep, 0, self.n_decaystep),
#      63             decay_steps=self.n_decaystep, decay_rate=self.decay_rate, staircase=False), dtype=tf_floattype)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Attempt to convert a value (functools.partial(<tensorflow.python.keras.optimizer_v2.learning_rate_schedule.ExponentialDecay object at 0x7f81eac334f0>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)) with an unsupported type (<class 'functools.partial'>) to a Tensor.

# %%
import
